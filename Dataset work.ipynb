# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm

import matplotlib.pyplot as plt
import matplotlib as mlp
# %matplotlib inline

# %% [markdown]
# Most lab tasks deal with classification problems. Since we chose a data set with a numerical output (i.e. a regression problem) we needed discretize our output variable into categories/classes

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Year      Country  Happiness Rank  Happiness Score  \
# 0           0  2015  Switzerland               1            7.587
# 1           1  2015      Iceland               2            7.561
# 2           2  2015      Denmark               3            7.527
# 3           3  2015       Norway               4            7.522
# 4           4  2015       Canada               5            7.427
#
#    GDP per Capita  Social support  Life Expectancy  \
# 0         1.39651         1.34951          0.94143
# 1         1.30232         1.40223          0.94784
# 2         1.32548         1.36058          0.87464
# 3         1.45900         1.33095          0.88521
# 4         1.32629         1.32261          0.90563
#
#    Freedom to make life choices  Perceptions of corruption  Generosity
# 0                       0.66557                    0.41978     0.29678
# 1                       0.62877                    0.14145     0.43630
# 2                       0.64938                    0.48357     0.34139
# 3                       0.66973                    0.36503     0.34699
# 4                       0.63297                    0.32957     0.45811

# %%
df_copy = df.drop(df.columns[0], axis=1)

# %%
df_copy.head()
# Out:
#    Year      Country  Happiness Rank  Happiness Score  GDP per Capita  \
# 0  2015  Switzerland               1            7.587         1.39651
# 1  2015      Iceland               2            7.561         1.30232
# 2  2015      Denmark               3            7.527         1.32548
# 3  2015       Norway               4            7.522         1.45900
# 4  2015       Canada               5            7.427         1.32629
#
#    Social support  Life Expectancy  Freedom to make life choices  \
# 0         1.34951          0.94143                       0.66557
# 1         1.40223          0.94784                       0.62877
# 2         1.36058          0.87464                       0.64938
# 3         1.33095          0.88521                       0.66973
# 4         1.32261          0.90563                       0.63297
#
#    Perceptions of corruption  Generosity
# 0                    0.41978     0.29678
# 1                    0.14145     0.43630
# 2                    0.48357     0.34139
# 3                    0.36503     0.34699
# 4                    0.32957     0.45811

# %% [markdown]
# # Add Category Column to pandas DataFrame with cut

# %% [markdown]
# ## 3-class categorization

# %% [markdown]
# For now the simpest way to categorize the countries would be through the happiness rank as follows :
# - 1st tier : 1-52
# - 2nd tier : 53- 105
# - 3rd tier : 106 - 158

# %%
df_copy["tier"] = pd.cut(
    x=df["Happiness Rank"],
    bins=[0, 53, 106, np.inf],
    labels=["First", "Second", "Third"])

# %%
df_copy.head()
# Out:
#    Year      Country  Happiness Rank  Happiness Score  GDP per Capita  \
# 0  2015  Switzerland               1            7.587         1.39651
# 1  2015      Iceland               2            7.561         1.30232
# 2  2015      Denmark               3            7.527         1.32548
# 3  2015       Norway               4            7.522         1.45900
# 4  2015       Canada               5            7.427         1.32629
#
#    Social support  Life Expectancy  Freedom to make life choices  \
# 0         1.34951          0.94143                       0.66557
# 1         1.40223          0.94784                       0.62877
# 2         1.36058          0.87464                       0.64938
# 3         1.33095          0.88521                       0.66973
# 4         1.32261          0.90563                       0.63297
#
#    Perceptions of corruption  Generosity   tier
# 0                    0.41978     0.29678  First
# 1                    0.14145     0.43630  First
# 2                    0.48357     0.34139  First
# 3                    0.36503     0.34699  First
# 4                    0.32957     0.45811  First

# %%
df_copy.tail()
# Out:
#      Year      Country  Happiness Rank  Happiness Score  GDP per Capita  \
# 926  2021      Lesotho             145            3.512           0.451
# 927  2021     Botswana             146            3.467           1.099
# 928  2021       Rwanda             147            3.415           0.364
# 929  2021     Zimbabwe             148            3.145           0.457
# 930  2021  Afghanistan             149            2.523           0.370
#
#      Social support  Life Expectancy  Freedom to make life choices  \
# 926           0.731            0.007                         0.405
# 927           0.724            0.340                         0.539
# 928           0.202            0.407                         0.627
# 929           0.649            0.243                         0.359
# 930           0.000            0.126                         0.000
#
#      Perceptions of corruption  Generosity   tier
# 926                      0.015       0.103  Third
# 927                      0.088       0.027  Third
# 928                      0.493       0.227  Third
# 929                      0.075       0.157  Third
# 930                      0.010       0.122  Third

# %%
df_copy.to_csv('data_cat1.csv')

# %% [markdown]
# ## 2-class categorization

# %%
df2 = df

# %%
df2 = df2.drop(df.columns[0], axis=1)

# %%
df2.head()
# Out:
#    Year      Country  Happiness Rank  Happiness Score  GDP per Capita  \
# 0  2015  Switzerland               1            7.587         1.39651
# 1  2015      Iceland               2            7.561         1.30232
# 2  2015      Denmark               3            7.527         1.32548
# 3  2015       Norway               4            7.522         1.45900
# 4  2015       Canada               5            7.427         1.32629
#
#    Social support  Life Expectancy  Freedom to make life choices  \
# 0         1.34951          0.94143                       0.66557
# 1         1.40223          0.94784                       0.62877
# 2         1.36058          0.87464                       0.64938
# 3         1.33095          0.88521                       0.66973
# 4         1.32261          0.90563                       0.63297
#
#    Perceptions of corruption  Generosity
# 0                    0.41978     0.29678
# 1                    0.14145     0.43630
# 2                    0.48357     0.34139
# 3                    0.36503     0.34699
# 4                    0.32957     0.45811

# %%
df2["tier"] = pd.cut(
    x=df["Happiness Rank"],
    bins=[0, 78, np.inf],
    labels=["First", "Second"])

# %%
df2.head()
# Out:
#    Year      Country  Happiness Rank  Happiness Score  GDP per Capita  \
# 0  2015  Switzerland               1            7.587         1.39651
# 1  2015      Iceland               2            7.561         1.30232
# 2  2015      Denmark               3            7.527         1.32548
# 3  2015       Norway               4            7.522         1.45900
# 4  2015       Canada               5            7.427         1.32629
#
#    Social support  Life Expectancy  Freedom to make life choices  \
# 0         1.34951          0.94143                       0.66557
# 1         1.40223          0.94784                       0.62877
# 2         1.36058          0.87464                       0.64938
# 3         1.33095          0.88521                       0.66973
# 4         1.32261          0.90563                       0.63297
#
#    Perceptions of corruption  Generosity   tier
# 0                    0.41978     0.29678  First
# 1                    0.14145     0.43630  First
# 2                    0.48357     0.34139  First
# 3                    0.36503     0.34699  First
# 4                    0.32957     0.45811  First

# %%
df2.to_csv('data_2_cat.csv')
